-- %% [markdown]
-- # [dbo].[ano]

-- %%
USE [taller]
GO

-- %%
/****** Object:  Table [dbo].[ano]    Script Date: 12/04/2025 10:40:31 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ano](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[token] [varchar](32) NOT NULL,
	[ano] [varchar](25) NOT NULL,
	[estatus] [int] NOT NULL,
 CONSTRAINT [PK_ano] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[categoria]

-- %%
/****** Object:  Table [dbo].[categoria]    Script Date: 12/04/2025 10:40:31 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[categoria](
	[id] [int] NOT NULL,
	[token] [varchar](32) NOT NULL,
	[categoria] [varchar](25) NOT NULL,
	[estatus] [int] NOT NULL,
 CONSTRAINT [PK_categoria] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[clientes]

-- %%
/****** Object:  Table [dbo].[clientes]    Script Date: 12/04/2025 10:40:31 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[clientes](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[token] [varchar](32) NOT NULL,
	[nombre] [varchar](25) NOT NULL,
	[direccion] [varchar](25) NOT NULL,
	[telefono] [varchar](10) NOT NULL,
	[localidad] [varchar](20) NOT NULL,
	[observaciones] [varchar](30) NOT NULL,
	[estatus] [int] NOT NULL,
 CONSTRAINT [PK_clientes] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[inventario]

-- %%
/****** Object:  Table [dbo].[inventario]    Script Date: 12/04/2025 10:40:31 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[inventario](
	[idrefaccion] [varchar](20) NOT NULL,
	[idusuario] [varchar](25) NOT NULL,
	[cantidad] [float] NOT NULL,
	[tipomovimiento] [varchar](10) NOT NULL,
	[fecha] [datetime2](0) NOT NULL,
	[observaciones] [varchar](15) NOT NULL,
 CONSTRAINT [PK_inventario] PRIMARY KEY CLUSTERED 
(
	[idrefaccion] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[marca]

-- %%
/****** Object:  Table [dbo].[marca]    Script Date: 12/04/2025 10:40:31 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[marca](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[token] [varchar](32) NOT NULL,
	[marca] [varchar](25) NOT NULL,
	[estatus] [int] NOT NULL,
 CONSTRAINT [PK_marca] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ordenes]

-- %%
/****** Object:  Table [dbo].[ordenes]    Script Date: 12/04/2025 10:40:31 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ordenes](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[token] [varchar](32) NOT NULL,
	[fecha] [datetime2](0) NOT NULL,
	[concepto] [varchar](15) NOT NULL,
	[nivelcombustible] [varchar](max) NOT NULL,
	[kilometros] [int] NOT NULL,
	[estatus] [int] NOT NULL,
	[idusuario] [int] NOT NULL,
	[idvehiculo] [int] NOT NULL,
	[idservicio] [int] NOT NULL,
 CONSTRAINT [PK_ordenes] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[presupuesto]

-- %%
/****** Object:  Table [dbo].[presupuesto]    Script Date: 12/04/2025 10:40:31 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[presupuesto](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[token] [varchar](32) NOT NULL,
	[fecha] [datetime2](0) NOT NULL,
	[concepto] [varchar](15) NOT NULL,
	[idcliente] [int] NOT NULL,
	[idvehiculo] [int] NOT NULL,
	[idrefaccion] [int] NOT NULL,
	[idservicio] [int] NOT NULL,
	[descripcion] [varchar](25) NOT NULL,
	[estatus] [int] NOT NULL,
 CONSTRAINT [PK_presupuesto] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[refacciones]

-- %%
/****** Object:  Table [dbo].[refacciones]    Script Date: 12/04/2025 10:40:31 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[refacciones](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[token] [varchar](32) NOT NULL,
	[codigo] [varchar](15) NOT NULL,
	[nombre] [varchar](15) NOT NULL,
	[unidadmedida] [varchar](max) NOT NULL,
	[marca] [varchar](15) NOT NULL,
	[stock] [int] NOT NULL,
	[proveedor] [varchar](15) NOT NULL,
	[preciocompra] [float] NOT NULL,
	[precioventa] [float] NOT NULL,
	[descripcion] [varchar](25) NOT NULL,
	[estatus] [int] NOT NULL,
 CONSTRAINT [PK_refacciones] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[servicio]

-- %%
/****** Object:  Table [dbo].[servicio]    Script Date: 12/04/2025 10:40:31 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[servicio](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[token] [varchar](32) NOT NULL,
	[nombreservicio] [varchar](20) NOT NULL,
	[costomobra] [int] NOT NULL,
	[descripcion] [varchar](30) NOT NULL,
	[estatus] [int] NOT NULL,
 CONSTRAINT [PK_servicio] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[telefono]

-- %%
/****** Object:  Table [dbo].[telefono]    Script Date: 12/04/2025 10:40:31 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[telefono](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[token] [varchar](32) NOT NULL,
	[telefono] [varchar](10) NOT NULL,
	[estatus] [int] NOT NULL,
 CONSTRAINT [PK_telefono] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[usuarios]

-- %%
/****** Object:  Table [dbo].[usuarios]    Script Date: 12/04/2025 10:40:31 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[usuarios](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[token] [varchar](32) NOT NULL,
	[nombre] [varchar](25) NOT NULL,
	[correo] [varchar](25) NOT NULL,
	[password] [varchar](max) NOT NULL,
	[estatus] [int] NOT NULL,
 CONSTRAINT [PK_usuarios] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[vehiculo]

-- %%
/****** Object:  Table [dbo].[vehiculo]    Script Date: 12/04/2025 10:40:31 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[vehiculo](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[token] [varchar](32) NOT NULL,
	[tipo] [varchar](max) NOT NULL,
	[idano] [int] NOT NULL,
	[idmarca] [int] NOT NULL,
	[placa] [varchar](10) NOT NULL,
	[vin] [varchar](20) NOT NULL,
	[color] [varchar](15) NOT NULL,
	[idcliente] [int] NOT NULL,
	[model] [varchar](30) NOT NULL,
	[estatus] [int] NOT NULL,
 CONSTRAINT [PK_vehiculo] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ano]

-- %%
SET IDENTITY_INSERT [dbo].[ano] ON 
INSERT [dbo].[ano] ([id], [token], [ano], [estatus]) VALUES (132, N'7199f35dcd6c23d04309057fbe3c512e', N'2030', 1)
INSERT [dbo].[ano] ([id], [token], [ano], [estatus]) VALUES (167, N'7199f35dcd6c23d04309057fbe3c512e', N'2030', 1)
INSERT [dbo].[ano] ([id], [token], [ano], [estatus]) VALUES (168, N'7199f35dcd6c23d04309057fbe3c512e', N'2030', 1)
INSERT [dbo].[ano] ([id], [token], [ano], [estatus]) VALUES (169, N'6c9795e14396ceffa94d64fb8892037f', N'2021', 1)
INSERT [dbo].[ano] ([id], [token], [ano], [estatus]) VALUES (171, N'a416c99dc8d018dcdcadd262010cb337', N'2025', 1)
SET IDENTITY_INSERT [dbo].[ano] OFF
GO

-- %% [markdown]
-- # [dbo].[clientes]

-- %%
SET IDENTITY_INSERT [dbo].[clientes] ON 
INSERT [dbo].[clientes] ([id], [token], [nombre], [direccion], [telefono], [localidad], [observaciones], [estatus]) VALUES (18, N'6ac6dcbeebcbd0b247fe9b7b5813c708', N'cupertino diez', N'cliente uno', N'2487850110', N'cuacnopalan', N'no hay', 1)
INSERT [dbo].[clientes] ([id], [token], [nombre], [direccion], [telefono], [localidad], [observaciones], [estatus]) VALUES (19, N'40baa570707dddf9a27dcc06b91b2c50', N'alan robles', N'n cliene', N'2487596002', N'cuacnopalan', N'no hay desc', 1)
INSERT [dbo].[clientes] ([id], [token], [nombre], [direccion], [telefono], [localidad], [observaciones], [estatus]) VALUES (20, N'ff96bd396700c4575fba19849062b9ae', N'said roman', N'  direccion', N'0120000000', N'cuacnopalan', N'no ', 1)
INSERT [dbo].[clientes] ([id], [token], [nombre], [direccion], [telefono], [localidad], [observaciones], [estatus]) VALUES (21, N'f179f62027e9984bb1aac3aa247657b9', N'said sosa roman', N'8sur 503', N'2225486001', N'puebla palam', N'no hay', 1)
SET IDENTITY_INSERT [dbo].[clientes] OFF
GO

-- %% [markdown]
-- # [dbo].[marca]

-- %%
SET IDENTITY_INSERT [dbo].[marca] ON 
INSERT [dbo].[marca] ([id], [token], [marca], [estatus]) VALUES (1010, N'd00867667bc907a44977f0d388b7cc79', N'ford', 1)
INSERT [dbo].[marca] ([id], [token], [marca], [estatus]) VALUES (1011, N'2ca7225b4ac0d90d846c248f6ccb4437', N'honda', 1)
INSERT [dbo].[marca] ([id], [token], [marca], [estatus]) VALUES (1012, N'98a75df4f068947dd9cbaf822f35cdc2', N'nissan', 1)
SET IDENTITY_INSERT [dbo].[marca] OFF
GO

-- %% [markdown]
-- # [dbo].[refacciones]

-- %%
SET IDENTITY_INSERT [dbo].[refacciones] ON 
INSERT [dbo].[refacciones] ([id], [token], [codigo], [nombre], [unidadmedida], [marca], [stock], [proveedor], [preciocompra], [precioventa], [descripcion], [estatus]) VALUES (1, N'6593669f8289bdd6a5108d375641533e', N'0256515', N'filtro gasolina', N'Unidad', N'stp', 10, N'AUTOZONE', 48, 65, N'sin comentarios
', 1)
SET IDENTITY_INSERT [dbo].[refacciones] OFF
GO

-- %% [markdown]
-- # [dbo].[servicio]

-- %%
SET IDENTITY_INSERT [dbo].[servicio] ON 
INSERT [dbo].[servicio] ([id], [token], [nombreservicio], [costomobra], [descripcion], [estatus]) VALUES (1, N'83e36c57e56eb8fa5e26fcf1bb63a361', N'cambio aceite', 250, N'nombre', 1)
INSERT [dbo].[servicio] ([id], [token], [nombreservicio], [costomobra], [descripcion], [estatus]) VALUES (2, N'a80e653364c8d8a5d066c243957caa31', N'cambio rotulas', 250, N'rotulas superio', 1)
INSERT [dbo].[servicio] ([id], [token], [nombreservicio], [costomobra], [descripcion], [estatus]) VALUES (4, N'217498c76e72626a71c4a3280545c95b', N'servicio', 100, N'2', 0)
INSERT [dbo].[servicio] ([id], [token], [nombreservicio], [costomobra], [descripcion], [estatus]) VALUES (5, N'60f0592b079002d7012800929907fadf', N'prueba larga', 145, N'servicio urgente cliente 03', 1)
INSERT [dbo].[servicio] ([id], [token], [nombreservicio], [costomobra], [descripcion], [estatus]) VALUES (7, N'bd5404024c7b7fbbab2882c9abb9352e', N'homocineticas', 100, N'rr', 1)
INSERT [dbo].[servicio] ([id], [token], [nombreservicio], [costomobra], [descripcion], [estatus]) VALUES (8, N'128b430a0eef9555eff85537864584b3', N'prueba larga de serv', 32, N'descripcion del cambio jnjeje', 1)
INSERT [dbo].[servicio] ([id], [token], [nombreservicio], [costomobra], [descripcion], [estatus]) VALUES (9, N'128b430a0eef9555eff85537864584b3', N'prueba larga de serv', 32, N'descripcion del cambio jnjeje', 1)
INSERT [dbo].[servicio] ([id], [token], [nombreservicio], [costomobra], [descripcion], [estatus]) VALUES (10, N'7ff4bac6302895ee38b688cbd7a9475d', N'afinacion', 500, N'no', 1)
INSERT [dbo].[servicio] ([id], [token], [nombreservicio], [costomobra], [descripcion], [estatus]) VALUES (11, N'c7c56f21dc9927b6ade79567da7efc35', N'cambio transmision', 1500, N'des', 1)
SET IDENTITY_INSERT [dbo].[servicio] OFF
GO

-- %% [markdown]
-- # [dbo].[usuarios]

-- %%
SET IDENTITY_INSERT [dbo].[usuarios] ON 
INSERT [dbo].[usuarios] ([id], [token], [nombre], [correo], [password], [estatus]) VALUES (33, N'c0bc2a5dd1c7d8efe731a4b9a99d1400', N'eric perez flores', N'eric@gmail.com', N'$2a$07$Plu590nEp1uS9Pr0hA55eelqKhjyHSwkfGx6imJOBBrv4bzyAszuy', 1)
INSERT [dbo].[usuarios] ([id], [token], [nombre], [correo], [password], [estatus]) VALUES (35, N'e36ff417dd658628935a4b349a0e03fc', N'ruben prueba dos', N'rube44@aol.com', N'$2a$07$Plu590nEp1uS9Pr0hA55eencq9ZqU8H0zHdqCOh66mu3bbx1E0nyW', 0)
INSERT [dbo].[usuarios] ([id], [token], [nombre], [correo], [password], [estatus]) VALUES (36, N'bc5e4f9e542f8787c97f6763614a5c36', N'juanito barraza', N'juanito22@gmail.com', N'$2a$07$Plu590nEp1uS9Pr0hA55eencq9ZqU8H0zHdqCOh66mu3bbx1E0nyW', 1)
INSERT [dbo].[usuarios] ([id], [token], [nombre], [correo], [password], [estatus]) VALUES (45, N'df7db2b490eb922da3a4d7d74a278506', N'marianita silva r', N'marixal@aol.com', N'$2a$07$Plu590nEp1uS9Pr0hA55eencq9ZqU8H0zHdqCOh66mu3bbx1E0nyW', 1)
INSERT [dbo].[usuarios] ([id], [token], [nombre], [correo], [password], [estatus]) VALUES (46, N'a46680bf9babb7ab377480d270664066', N'tobon tobon gabriela', N'tobongaby@gmail.com', N'$2a$07$Plu590nEp1uS9Pr0hA55eelqKhjyHSwkfGx6imJOBBrv4bzyAszuy', 1)
INSERT [dbo].[usuarios] ([id], [token], [nombre], [correo], [password], [estatus]) VALUES (58, N'6288e7a7d7089953523fbaffb5a9c269', N'pepita pinga', N'pingatinda@aol.com', N'$2a$07$Plu590nEp1uS9Pr0hA55eelqKhjyHSwkfGx6imJOBBrv4bzyAszuy', 1)
INSERT [dbo].[usuarios] ([id], [token], [nombre], [correo], [password], [estatus]) VALUES (75, N'cdf99acc087eb241f2c336ff63269588', N'Ernesto perez', N'ernesto@correo.com', N'$2a$07$Plu590nEp1uS9Pr0hA55eesaF.2fORssTfRhUVFvTbPFpSU9OJrL.', 1)
INSERT [dbo].[usuarios] ([id], [token], [nombre], [correo], [password], [estatus]) VALUES (86, N'd429b7e52e7bc2e537dcdefe1aec9e0d', N'sonia rojas teon', N'songia@gmail.com', N'$2a$07$Plu590nEp1uS9Pr0hA55eencq9ZqU8H0zHdqCOh66mu3bbx1E0nyW', 1)
SET IDENTITY_INSERT [dbo].[usuarios] OFF
GO

-- %% [markdown]
-- # [dbo].[vehiculo]

-- %%
SET IDENTITY_INSERT [dbo].[vehiculo] ON 
INSERT [dbo].[vehiculo] ([id], [token], [tipo], [idano], [idmarca], [placa], [vin], [color], [idcliente], [model], [estatus]) VALUES (2, N'ca1c5c0193098a5171ebd56e1f9c8313', N'Automovil', 33, 3, N'ush5122', N'3h151589se250211', N'rojo', 0, N'coche rines negross
', 1)
INSERT [dbo].[vehiculo] ([id], [token], [tipo], [idano], [idmarca], [placa], [vin], [color], [idcliente], [model], [estatus]) VALUES (6, N'2a72ed48de17feba9bb4aea6bc59a137', N'Camioneta', 169, 1010, N'tua1578', N'2C3CDYBT9EH229923', N'azul', 18, N'6600', 1)
INSERT [dbo].[vehiculo] ([id], [token], [tipo], [idano], [idmarca], [placa], [vin], [color], [idcliente], [model], [estatus]) VALUES (10, N'513d561c681d7c98283662bb4d3e054f', N'Automovil', 167, 1010, N'bua1578', N'sesss30', N'azul', 20, N'f150', 1)
INSERT [dbo].[vehiculo] ([id], [token], [tipo], [idano], [idmarca], [placa], [vin], [color], [idcliente], [model], [estatus]) VALUES (15, N'2a72ed48de17feba9bb4aea6bc59a137', N'Camioneta', 169, 1010, N'tua1578', N'2C3CDYBT9EH229923', N'azul', 18, N'6600', 1)
INSERT [dbo].[vehiculo] ([id], [token], [tipo], [idano], [idmarca], [placa], [vin], [color], [idcliente], [model], [estatus]) VALUES (16, N'd390b7bcb21f31573f66f779e04a0526', N'Tractor', 168, 1011, N'eua15754', N'2C3CDYBT9EH22992', N'rojo', 19, N'f150', 1)
INSERT [dbo].[vehiculo] ([id], [token], [tipo], [idano], [idmarca], [placa], [vin], [color], [idcliente], [model], [estatus]) VALUES (17, N'6b7b47b44419b54260ee4e0100821fa1', N'Automovil', 132, 1010, N' ES0158', N'sesss30ss', N' rojo', 19, N' rav', 1)
INSERT [dbo].[vehiculo] ([id], [token], [tipo], [idano], [idmarca], [placa], [vin], [color], [idcliente], [model], [estatus]) VALUES (19, N'0957fce9c6929bdd3cd799d8a181422a', N'Tractor', 168, 1010, N'e3rr', N'err', N'azul', 20, N'ford', 1)
INSERT [dbo].[vehiculo] ([id], [token], [tipo], [idano], [idmarca], [placa], [vin], [color], [idcliente], [model], [estatus]) VALUES (22, N'04b66185d0210d0a8fe314016049d1b7', N'Automovil', 168, 1011, N'xxl', N'3vw', N'negro', 18, N'jetta', 1)
SET IDENTITY_INSERT [dbo].[vehiculo] OFF
GO

-- %% [markdown]
-- # [DF__ano__estatus__48CFD27E]

-- %%
ALTER TABLE [dbo].[ano] ADD  CONSTRAINT [DF__ano__estatus__48CFD27E]  DEFAULT ((1)) FOR [estatus]
GO

-- %% [markdown]
-- # [DF__clientes__estatu__4BAC3F29]

-- %%
ALTER TABLE [dbo].[clientes] ADD  CONSTRAINT [DF__clientes__estatu__4BAC3F29]  DEFAULT ((1)) FOR [estatus]
GO

-- %% [markdown]
-- # [DF__inventari__fecha__4D94879B]

-- %%
ALTER TABLE [dbo].[inventario] ADD  DEFAULT (getdate()) FOR [fecha]
GO

-- %% [markdown]
-- # [DF__marca__estatus__4F7CD00D]

-- %%
ALTER TABLE [dbo].[marca] ADD  CONSTRAINT [DF__marca__estatus__4F7CD00D]  DEFAULT ((1)) FOR [estatus]
GO

-- %% [markdown]
-- # [DF__ordenes__fecha__5165187F]

-- %%
ALTER TABLE [dbo].[ordenes] ADD  CONSTRAINT [DF__ordenes__fecha__5165187F]  DEFAULT (getdate()) FOR [fecha]
GO

-- %% [markdown]
-- # [DF__ordenes__estatus__52593CB8]

-- %%
ALTER TABLE [dbo].[ordenes] ADD  CONSTRAINT [DF__ordenes__estatus__52593CB8]  DEFAULT ((1)) FOR [estatus]
GO

-- %% [markdown]
-- # [DF__refaccion__estat__5535A963]

-- %%
ALTER TABLE [dbo].[refacciones] ADD  CONSTRAINT [DF__refaccion__estat__5535A963]  DEFAULT ((1)) FOR [estatus]
GO

-- %% [markdown]
-- # [DF__servicio__estatu__571DF1D5]

-- %%
ALTER TABLE [dbo].[servicio] ADD  CONSTRAINT [DF__servicio__estatu__571DF1D5]  DEFAULT ((1)) FOR [estatus]
GO

-- %% [markdown]
-- # [DF__telefono__estatu__59063A47]

-- %%
ALTER TABLE [dbo].[telefono] ADD  CONSTRAINT [DF__telefono__estatu__59063A47]  DEFAULT ((1)) FOR [estatus]
GO

-- %% [markdown]
-- # [DF__usuarios__estatu__5BE2A6F2]

-- %%
ALTER TABLE [dbo].[usuarios] ADD  CONSTRAINT [DF__usuarios__estatu__5BE2A6F2]  DEFAULT ((1)) FOR [estatus]
GO

-- %% [markdown]
-- # [DF__vehiculo__estatu__5DCAEF64]

-- %%
ALTER TABLE [dbo].[vehiculo] ADD  CONSTRAINT [DF__vehiculo__estatu__5DCAEF64]  DEFAULT ((1)) FOR [estatus]
GO

-- %% [markdown]
-- # [dbo].[actualizarAno]

-- %%
/****** Object:  StoredProcedure [dbo].[actualizarAno]    Script Date: 12/04/2025 10:40:31 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE  PROCEDURE [dbo].[actualizarAno] ( @inAno INT, @inToken VARCHAR(max), @Filtrotoken VARCHAR(max))   AS
   BEGIN
   SET NOCOUNT ON;
	UPDATE ano set ano = @inAno,
            token = @inToken
            WHERE token = @Filtrotoken;
END
GO

-- %% [markdown]
-- # [dbo].[actualizarCliente]

-- %%
/****** Object:  StoredProcedure [dbo].[actualizarCliente]    Script Date: 12/04/2025 10:40:31 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE  PROCEDURE [dbo].[actualizarCliente] (@inNombre VARCHAR(25), @inDireccion VARCHAR(25), @inTelefono VARCHAR(10), @inLocalidad VARCHAR(20), @inObservaciones VARCHAR(30), @inToken VARCHAR(max), @Filtrotoken VARCHAR(max))   AS
   BEGIN
   SET NOCOUNT ON;
UPDATE clientes set nombre = @inNombre,
            direccion = @inDireccion,
            telefono = @inTelefono,
            localidad = @inLocalidad,
            observaciones = @inObservaciones,
            token = @inToken
            WHERE token = @Filtrotoken;
END
GO

-- %% [markdown]
-- # [dbo].[actualizarInventario]

-- %%
/****** Object:  StoredProcedure [dbo].[actualizarInventario]    Script Date: 12/04/2025 10:40:31 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE  PROCEDURE [dbo].[actualizarInventario] ( @inNombre VARCHAR(15), @inMovimiento VARCHAR(10), @inUsuario VARCHAR(35))   AS
   BEGIN
   SET NOCOUNT ON;
  INSERT INTO inventario
 (idrefaccion, tipomovimiento, idusuario)
 VALUES
 (@inNombre, @inMovimiento, @inUsuario);
END
GO

-- %% [markdown]
-- # [dbo].[actualizarMarca]

-- %%
/****** Object:  StoredProcedure [dbo].[actualizarMarca]    Script Date: 12/04/2025 10:40:31 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE  PROCEDURE [dbo].[actualizarMarca] ( @inMarca VARCHAR(25), @inToken VARCHAR(max), @Filtrotoken VARCHAR(max))   AS
   BEGIN
   SET NOCOUNT ON;
	UPDATE marca set marca = @inMarca,
            token = @inToken
            WHERE token = @Filtrotoken;
END
GO

-- %% [markdown]
-- # [dbo].[actualizarOrden]

-- %%
/****** Object:  StoredProcedure [dbo].[actualizarOrden]    Script Date: 12/04/2025 10:40:31 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE  PROCEDURE [dbo].[actualizarOrden] ( @inVehiculo INT, @inConcepto VARCHAR(15), @inCombustible VARCHAR(max), @inKilometros INT, @inTecnico INT, @inServicio VARCHAR(15), @inToken VARCHAR(max), @Filtrotoken VARCHAR(max))   AS
   BEGIN
   SET NOCOUNT ON;
	UPDATE ordenes set idvehiculo = @inVehiculo,
            concepto = @inConcepto,
            nivelcombustible = @inCombustible,
            kilometros = @inKilometros,
            idusuario = @inTecnico,
            idservicio = @inServicio,
            token = @inToken
            WHERE token = @Filtrotoken;
END
GO

-- %% [markdown]
-- # [dbo].[actualizarRefaccion]

-- %%
/****** Object:  StoredProcedure [dbo].[actualizarRefaccion]    Script Date: 12/04/2025 10:40:31 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE  PROCEDURE [dbo].[actualizarRefaccion] ( @inNombre VARCHAR(15), @inUnidad VARCHAR(max), @inMarca VARCHAR(15), @inProveedor VARCHAR(15), @inVenta FLOAT, @inCompra FLOAT, @inDescripcion VARCHAR(25), @inToken VARCHAR(max))   AS
   BEGIN
   SET NOCOUNT ON;
	UPDATE refacciones set nombre = @inNombre,
            unidadmedida = @inUnidad,
            marca = @inMarca,
            proveedor = @inProveedor,
            precioventa = @inVenta,
            preciocompra = @inCompra,
            descripcion = @inDescripcion
            WHERE token = @inToken;
END
GO

-- %% [markdown]
-- # [dbo].[actualizarServicio]

-- %%
/****** Object:  StoredProcedure [dbo].[actualizarServicio]    Script Date: 12/04/2025 10:40:31 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE  PROCEDURE [dbo].[actualizarServicio] ( @inNombreservicio VARCHAR(20), @inCostomobra INT, @inDescripcion VARCHAR(30), @inToken VARCHAR(max), @Filtrotoken VARCHAR(max))   AS
   BEGIN
   SET NOCOUNT ON;
	UPDATE servicio set nombreservicio = @inNombreservicio,
			costomobra = @inCostomobra, 
            descripcion = @inDescripcion,
            token = @inToken
            WHERE token = @Filtrotoken;
END
GO

-- %% [markdown]
-- # [dbo].[actualizarTelefono]

-- %%
/****** Object:  StoredProcedure [dbo].[actualizarTelefono]    Script Date: 12/04/2025 10:40:31 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE  PROCEDURE [dbo].[actualizarTelefono] ( @inTelefono VARCHAR(10), @inToken VARCHAR(max), @Filtrotoken VARCHAR(max))   AS
   BEGIN
   SET NOCOUNT ON;
	UPDATE telefono set telefono = @inTelefono,
            token = @inToken
            WHERE token = @Filtrotoken;
END
GO

-- %% [markdown]
-- # [dbo].[actualizarUsuario]

-- %%
/****** Object:  StoredProcedure [dbo].[actualizarUsuario]    Script Date: 12/04/2025 10:40:31 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE  PROCEDURE [dbo].[actualizarUsuario] ( @inNombre VARCHAR(30), @inEmail VARCHAR(25), @inPassword VARCHAR(max), @inToken VARCHAR(max), @Filtrotoken VARCHAR(max))   AS
   BEGIN
   SET NOCOUNT ON;
	UPDATE usuarios set nombre = @inNombre,
            correo = @inEmail,
            password = @inPassword,
            token = @inToken
            WHERE token = @Filtrotoken;
END
GO

-- %% [markdown]
-- # [dbo].[actualizarVehiculo]

-- %%
/****** Object:  StoredProcedure [dbo].[actualizarVehiculo]    Script Date: 12/04/2025 10:40:31 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE  PROCEDURE [dbo].[actualizarVehiculo] ( @inTipo VARCHAR(max), @inPlaca VARCHAR(10), @inMarca INT, @inModelo VARCHAR(30), @inAno INT, @inVin VARCHAR(20), @inColor VARCHAR(15), @inCliente INT, @inToken VARCHAR(max), @Filtrotoken VARCHAR(max))   AS
   BEGIN
   SET NOCOUNT ON;
	UPDATE vehiculo set tipo = @inTipo,
            placa = @inPlaca,
            idmarca = @inMarca,
			model = @inModelo,
            idano = @inAno,
            vin = @inVin,
            color = @inColor,
            idcliente = @inCliente,
            token = @inToken
            WHERE token = @Filtrotoken;
END
GO

-- %% [markdown]
-- # [dbo].[actualizaStockVenta]

-- %%
/****** Object:  StoredProcedure [dbo].[actualizaStockVenta]    Script Date: 12/04/2025 10:40:31 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE  PROCEDURE [dbo].[actualizaStockVenta] ( @inCantidad INT, @inRefaccion VARCHAR(max))   AS
   BEGIN
   SET NOCOUNT ON;
	UPDATE refacciones 
		SET stock = stock - @inCantidad
		WHERE token = @inRefaccion;
END
GO

-- %% [markdown]
-- # [dbo].[eliminarAnoVehiculo]

-- %%
/****** Object:  StoredProcedure [dbo].[eliminarAnoVehiculo]    Script Date: 12/04/2025 10:40:31 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE  PROCEDURE [dbo].[eliminarAnoVehiculo] ( @filtroToken VARCHAR(max))   AS
   BEGIN
   SET NOCOUNT ON;
	UPDATE ano 
    SET estatus = 0 
    WHERE token = @filtroToken;
END
GO

-- %% [markdown]
-- # [dbo].[eliminarCliente]

-- %%
/****** Object:  StoredProcedure [dbo].[eliminarCliente]    Script Date: 12/04/2025 10:40:31 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE  PROCEDURE [dbo].[eliminarCliente] (@filtroToken VARCHAR(max))   AS
   BEGIN
   SET NOCOUNT ON;
	UPDATE clientes 
    SET estatus = 0 
    WHERE token = @filtroToken;
END

GO

-- %% [markdown]
-- # [dbo].[eliminarMarca]

-- %%
/****** Object:  StoredProcedure [dbo].[eliminarMarca]    Script Date: 12/04/2025 10:40:31 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE  PROCEDURE [dbo].[eliminarMarca] ( @filtroToken VARCHAR(max))   AS
   BEGIN
   SET NOCOUNT ON;
	UPDATE marca 
    SET estatus = 0 
    WHERE token = @filtroToken;
END
GO

-- %% [markdown]
-- # [dbo].[eliminarModelo]

-- %%
/****** Object:  StoredProcedure [dbo].[eliminarModelo]    Script Date: 12/04/2025 10:40:31 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE  PROCEDURE [dbo].[eliminarModelo] ( @filtroToken VARCHAR(max))   AS
   BEGIN
   SET NOCOUNT ON;
	UPDATE ano 
    SET estatus = 0 
    WHERE token = @filtroToken;
END
GO

-- %% [markdown]
-- # [dbo].[eliminarOrden]

-- %%
/****** Object:  StoredProcedure [dbo].[eliminarOrden]    Script Date: 12/04/2025 10:40:31 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE  PROCEDURE [dbo].[eliminarOrden] ( @filtroToken VARCHAR(max))   AS
   BEGIN
   SET NOCOUNT ON;
	UPDATE ordenes 
    SET estatus = 0 
    WHERE token = @filtroToken;
END
GO

-- %% [markdown]
-- # [dbo].[eliminarRefaccion]

-- %%
/****** Object:  StoredProcedure [dbo].[eliminarRefaccion]    Script Date: 12/04/2025 10:40:31 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE  PROCEDURE [dbo].[eliminarRefaccion] ( @filtroToken VARCHAR(max))   AS
   BEGIN
   SET NOCOUNT ON;
	UPDATE refacciones 
    SET estatus = 0 
    WHERE token = @filtroToken;
END
GO

-- %% [markdown]
-- # [dbo].[eliminarServicio]

-- %%
/****** Object:  StoredProcedure [dbo].[eliminarServicio]    Script Date: 12/04/2025 10:40:31 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE  PROCEDURE [dbo].[eliminarServicio] ( @filtroToken VARCHAR(max))   AS
   BEGIN
   SET NOCOUNT ON;
	UPDATE servicio 
    SET estatus = 0 
    WHERE token = @filtroToken;
END
GO

-- %% [markdown]
-- # [dbo].[eliminarTelefono]

-- %%
/****** Object:  StoredProcedure [dbo].[eliminarTelefono]    Script Date: 12/04/2025 10:40:31 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE  PROCEDURE [dbo].[eliminarTelefono] ( @filtroToken VARCHAR(max))   AS
   BEGIN
   SET NOCOUNT ON;
	UPDATE telefono 
    SET estatus = 0 
    WHERE token = @filtroToken;
END
GO

-- %% [markdown]
-- # [dbo].[eliminarUsuario]

-- %%
/****** Object:  StoredProcedure [dbo].[eliminarUsuario]    Script Date: 12/04/2025 10:40:31 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE  PROCEDURE [dbo].[eliminarUsuario] ( @filtroToken VARCHAR(max))   AS
   BEGIN
   SET NOCOUNT ON;
	UPDATE usuarios 
    SET estatus = 0 
    WHERE token = @filtroToken;
END
GO

-- %% [markdown]
-- # [dbo].[eliminarVehiculo]

-- %%
/****** Object:  StoredProcedure [dbo].[eliminarVehiculo]    Script Date: 12/04/2025 10:40:31 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE  PROCEDURE [dbo].[eliminarVehiculo] ( @filtroToken VARCHAR(max))   AS
   BEGIN
   SET NOCOUNT ON;
	UPDATE vehiculo 
    SET estatus = 0 
    WHERE token = @filtroToken;
END
GO

-- %% [markdown]
-- # [dbo].[insertarAno]

-- %%
/****** Object:  StoredProcedure [dbo].[insertarAno]    Script Date: 12/04/2025 10:40:31 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE  PROCEDURE [dbo].[insertarAno] ( @inToken VARCHAR(max), @inAno INT)   AS
   BEGIN
   SET NOCOUNT ON;
 INSERT INTO ano
 (token, ano)
 VALUES
 (@inToken, @inAno);
END
GO

-- %% [markdown]
-- # [dbo].[insertarCliente]

-- %%
/****** Object:  StoredProcedure [dbo].[insertarCliente]    Script Date: 12/04/2025 10:40:31 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE  PROCEDURE [dbo].[insertarCliente] ( @inToken VARCHAR(max), @inNombre VARCHAR(25), @inDireccion VARCHAR(25), @inTelefono VARCHAR(10), @inLocalidad VARCHAR(20), @inObservaciones VARCHAR(30))   AS
   BEGIN
   SET NOCOUNT ON;
 INSERT INTO clientes
 (token, nombre, direccion, telefono, localidad, observaciones)
 VALUES
 (@inToken, @inNombre, @inDireccion, @inTelefono, @inLocalidad, @inObservaciones);
END
GO

-- %% [markdown]
-- # [dbo].[insertarInventario]

-- %%
/****** Object:  StoredProcedure [dbo].[insertarInventario]    Script Date: 12/04/2025 10:40:31 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE  PROCEDURE [dbo].[insertarInventario] ( @inNombre VARCHAR(15), @inStock FLOAT, @inMovimiento VARCHAR(10), @inUsuario VARCHAR(35))   AS
   BEGIN
   SET NOCOUNT ON;
  INSERT INTO inventario
 (idrefaccion, cantidad, tipomovimiento, idusuario)
 VALUES
 (@inNombre, @inStock, @inMovimiento, @inUsuario);
END
GO

-- %% [markdown]
-- # [dbo].[insertarMarca]

-- %%
/****** Object:  StoredProcedure [dbo].[insertarMarca]    Script Date: 12/04/2025 10:40:31 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE  PROCEDURE [dbo].[insertarMarca] ( @inToken VARCHAR(max), @inMarca VARCHAR(25))   AS
   BEGIN
   SET NOCOUNT ON;
 INSERT INTO marca
 (token, marca)
 VALUES
 (@inToken, @inMarca);
END
GO

-- %% [markdown]
-- # [dbo].[insertarOrden]

-- %%
/****** Object:  StoredProcedure [dbo].[insertarOrden]    Script Date: 12/04/2025 10:40:31 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE  PROCEDURE [dbo].[insertarOrden] ( @inToken VARCHAR(max), @inVehiculo INT, @inConcepto VARCHAR(15), @inCombustible VARCHAR(max), @inKilometros INT, @inTecnico INT, @inServicio VARCHAR(15))   AS
   BEGIN
   SET NOCOUNT ON;
 INSERT INTO ordenes
 (token, idvehiculo, concepto, nivelcombustible, kilometros, idusuario, idservicio)
 VALUES
 (@inToken, @inVehiculo, @inConcepto, @inCombustible, @inKilometros, @inTecnico, @inServicio);
END
GO

-- %% [markdown]
-- # [dbo].[insertarRefaccion]

-- %%
/****** Object:  StoredProcedure [dbo].[insertarRefaccion]    Script Date: 12/04/2025 10:40:31 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE  PROCEDURE [dbo].[insertarRefaccion] ( @inToken VARCHAR(max), @inCodigo VARCHAR(15), @inNombre VARCHAR(15), @inUnidad VARCHAR(max), @inMarca VARCHAR(15), @inStock INT, @inProveedor VARCHAR(15), @inVenta FLOAT, @inCompra FLOAT, @inDescripcion VARCHAR(25))   AS
   BEGIN
   SET NOCOUNT ON;
 INSERT INTO refacciones
 (token, codigo, nombre, unidadmedida, marca, stock, proveedor, precioventa,  preciocompra, descripcion)
 VALUES
 (@inToken, @inCodigo, @inNombre, @inUnidad, @inMarca, @inStock, @inProveedor, @inVenta, @inCompra, @inDescripcion);
END
GO

-- %% [markdown]
-- # [dbo].[insertarServicio]

-- %%
/****** Object:  StoredProcedure [dbo].[insertarServicio]    Script Date: 12/04/2025 10:40:31 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE  PROCEDURE [dbo].[insertarServicio] ( @inToken VARCHAR(max), @inNombreservicio VARCHAR(20), @inCostomobra INT, @inDescripcion VARCHAR(30))   AS
   BEGIN
   SET NOCOUNT ON;
 INSERT INTO servicio
 (token, nombreservicio, costomobra, descripcion)
 VALUES
 (@inToken, @inNombreservicio, @inCostomobra, @inDescripcion);
END
GO

-- %% [markdown]
-- # [dbo].[insertarTelefono]

-- %%
/****** Object:  StoredProcedure [dbo].[insertarTelefono]    Script Date: 12/04/2025 10:40:31 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE  PROCEDURE [dbo].[insertarTelefono] ( @inToken VARCHAR(max), @inTelefono VARCHAR(10))   AS
   BEGIN
   SET NOCOUNT ON;
 INSERT INTO telefono
 (token, telefono)
 VALUES
 (@inToken, @inTelefono);
END
GO

-- %% [markdown]
-- # [dbo].[insertarUsuario]

-- %%
/****** Object:  StoredProcedure [dbo].[insertarUsuario]    Script Date: 12/04/2025 10:40:31 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE  PROCEDURE [dbo].[insertarUsuario] ( @inToken VARCHAR(max), @inNombre VARCHAR(30), @inCorreo VARCHAR(25), @inPassword VARCHAR(max))   AS
   BEGIN
   SET NOCOUNT ON;
 INSERT INTO usuarios
 (token, nombre, correo, password)
 VALUES
 (@inToken, @inNombre, @inCorreo, @inPassword);
END
GO

-- %% [markdown]
-- # [dbo].[insertarVehiculo]

-- %%
/****** Object:  StoredProcedure [dbo].[insertarVehiculo]    Script Date: 12/04/2025 10:40:31 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE  PROCEDURE [dbo].[insertarVehiculo] ( @inToken VARCHAR(max), @inTipo VARCHAR(max), @inPlaca VARCHAR(10), @inMarca INT, @inModelo VARCHAR(30), @inAno INT, @inVin VARCHAR(20), @inColor VARCHAR(15), @inCliente INT ) AS
   BEGIN
   SET NOCOUNT ON;
 INSERT INTO vehiculo
 (token, tipo, placa, idmarca, model, idano, vin, color, idcliente)
 VALUES
 (@inToken, @inTipo, @inPlaca, @inMarca, @inModelo, @inAno, @inVin, @inColor, @inCliente);
END
GO

-- %% [markdown]
-- # [dbo].[seleccionarInventario]

-- %%
/****** Object:  StoredProcedure [dbo].[seleccionarInventario]    Script Date: 12/04/2025 10:40:31 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[seleccionarInventario] (@nombreTabla VARCHAR(MAX))
AS
BEGIN
    SET NOCOUNT ON;

    DECLARE @sql_text NVARCHAR(MAX);

    -- Crear el texto de la consulta dinámica
    SET @sql_text = N'SELECT * FROM ' + QUOTENAME(@nombreTabla);

    -- Ejecutar la consulta dinámica
    EXEC sp_executesql @sql_text;
END
GO

-- %% [markdown]
-- # [dbo].[seleccionarRegistro]

-- %%
/****** Object:  StoredProcedure [dbo].[seleccionarRegistro]    Script Date: 12/04/2025 10:40:31 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[seleccionarRegistro] (@nombreTabla VARCHAR(MAX), @nombreCampo VARCHAR(MAX), @valor VARCHAR(MAX))
AS
BEGIN
    SET NOCOUNT ON;

    DECLARE @sql_text NVARCHAR(MAX);

    -- Crear la consulta dinámica con los parámetros proporcionados
    SET @sql_text = N'SELECT * FROM ' + QUOTENAME(@nombreTabla) +
                    N' WHERE ' + QUOTENAME(@nombreCampo) + N' = @valor AND estatus = 1 ORDER BY id ASC;';

    -- Ejecutar la consulta dinámica usando sp_executesql y pasando el parámetro @valor
    EXEC sp_executesql @sql_text, N'@valor VARCHAR(MAX)', @valor;
END;

GO

-- %% [markdown]
-- # [dbo].[seleccionarRegistroOrden]

-- %%
/****** Object:  StoredProcedure [dbo].[seleccionarRegistroOrden]    Script Date: 12/04/2025 10:40:31 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE  PROCEDURE [dbo].[seleccionarRegistroOrden]   AS
   BEGIN
   SET NOCOUNT ON;
SELECT t1.concepto, t1.nivelcombustible, t1.kilometros, t1.fecha, t1.token, t2.placa, t3.nombreservicio, t4.nombre FROM ordenes t1 INNER JOIN vehiculo t2 ON t1.idvehiculo = t2.id 
INNER JOIN servicio t3 ON t1.idservicio = t3.id  INNER JOIN usuarios t4 ON t1.idusuario = t4.id  where t1.estatus = 1;
END
GO

-- %% [markdown]
-- # [dbo].[seleccionarRegistros]

-- %%
/****** Object:  StoredProcedure [dbo].[seleccionarRegistros]    Script Date: 12/04/2025 10:40:31 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[seleccionarRegistros] (@nombreTabla VARCHAR(MAX))
AS
BEGIN
    SET NOCOUNT ON;

    DECLARE @sql_text NVARCHAR(MAX);

    -- Crear la consulta dinámica
    SET @sql_text = N'SELECT * FROM ' + QUOTENAME(@nombreTabla) + N' WHERE estatus = 1 ORDER BY id ASC;';

    -- Ejecutar la consulta dinámica
    EXEC sp_executesql @sql_text;
END;
GO

-- %% [markdown]
-- # [dbo].[seleccionarRegistroVehiculo]

-- %%
/****** Object:  StoredProcedure [dbo].[seleccionarRegistroVehiculo]    Script Date: 12/04/2025 10:40:31 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE  PROCEDURE [dbo].[seleccionarRegistroVehiculo]   AS
   BEGIN
   SET NOCOUNT ON;
SELECT t1.tipo, t1.placa, t1.vin, t1.color, t1.model, t1.token, t2.ano, t3.marca, t4.nombre FROM vehiculo t1 INNER JOIN ano t2 ON t1.idano = t2.id 
    INNER JOIN marca t3 ON t1.idmarca = t3.id  INNER JOIN clientes t4 ON t1.idcliente = t4.id  where t1.estatus = 1;

END
GO

-- %% [markdown]
-- # [dbo].[seleccionarUsuario]

-- %%
/****** Object:  StoredProcedure [dbo].[seleccionarUsuario]    Script Date: 12/04/2025 10:40:31 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[seleccionarUsuario]
@correo VARCHAR(50),    
@pass VARCHAR(100)       
AS 
SELECT     
usuarios.id,     
usuarios.nombre,
usuarios.correo,   
usuarios.password
FROM       
usuarios
WHERE    
usuarios.correo = @correo   
AND usuarios.password = @pass
AND usuarios.estatus = 1    
GO
